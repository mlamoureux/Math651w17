# %% [markdown]
# # WaveSolver - slider
# M. Lamoureux May 31, 2016. Pacific Insitute for the Mathematical Sciences
#
# This code does some numerical simulation of wave propagation in 1D, suitable for demoing in a class.
#
# This is a rewrite of some of my old Julia code, translated to run in Python. My belief is that Python is a more mature system and I will likely be more productive by sticking to Python instead of Julia. Let's see if this is true.
#
# The code is based on formulas from the textbook Linear Partial Differential Equations for Scientists and Engineers, by Myint-U and Debnath. It's a good book -- you should buy it. Some extracts are also available online.
#
# In this Jupyter notebook, animation has been added, using GUI sliders to advance the waveform in time.
#
#
# This was also written as a test of how far we can push Bokeh and the Jupyter Hub in making some calculations and graphics. There is some dangerous code at the bottom, that can bring down our Jupyter Hub, probably because it eats up too much memory. Interesting for debugging purposes, but you have been warned.

# %% [markdown]
# ## Introduction to the 1D wave equation.
#
# The basic idea is to represent the vibrations of a (horizonal) string under tension by a function $u(x,t)$ where $x$ is the horizontal displacement along the string, $t$ is the time parameter, and $y=u(x,t)$ indicates the (vertical) displacement of the string at point $x$ along the string, at time $t$
#
# A typical wave would look something like
# $$u(x,t) = \sin(x-ct)$$
# which represents a sinusoidal wave moving to the right at velocity $c$.
#
# From Newon's law of motion (mass times acceleration equals force), we can derive the wave equation for the string in the form
# $$ \rho \cdot u_{tt} = k \cdot u_{xx}$$
# where $\rho$ is a mass density, $u_{tt}$ is an acceleration (the second derivative w.r.t. time), $k$ is the modulus of elasticity and $u_{xx}$ is a measure of curvature (the second derivative w.r.t. $x$), causing the bending force.
#
# Including boundary and initial conditions, while setting the parameter $c^2 = k/\rho$, we obtain the usual 1D wave equation on an interval as this:
#
#
# $$u_{tt} = c^2 u_{xx} \mbox{ on interval } [x_0,x_1]$$
# subject to boundary conditions
# $$u(x_0,t) = u(x_1, t) = 0 \mbox{ for all $t$. }$$
# and initial conditions
# $$u(x,0) = u_0(x), \quad u_t(x,t) = u_1(x) \mbox{ on interval } [x_0,x_1].$$
#
#
# Let's write some PDE solvers for this 1D wave equation.
#
# Start with some simple solvers, then get more complex.
#
# The function to solve the PDE needs to know $c^2, u_0, u_1$, the sampling intervals $dx$ and $dt$, and the number of time steps to execute. Everything else can be inferred from those inputs. The output should be a 2D array, indexed in x and t steps.
#
# Maybe we could actually output the solution $u(x,t)$ as well as the vector of indices for $x$ and $t$.

# %% [markdown]
# ## Software tools
# We import some tools for numerical work (NumPy) and plotting (Boken), using Boken because it is faster than matplotlib).

# %%
from bokeh.models import ColumnDataSource
from bokeh.plotting import *
from bokeh.io import push_notebook
import numpy as np

# %% [markdown]
# We also include some code from SciPy for numerical calculations

# %%
from scipy.linalg import solve_toeplitz  # a matrix equation solver
from scipy.integrate import cumtrapz # a numerical integrator, using trapezoid rule

# %% [markdown]
# And we include some code to create the graphical user interface -- namely, sliders. You can read about them here:
# http://bokeh.pydata.org/en/0.10.0/_images/notebook_interactors.png

# %%
from ipywidgets import interact

# %% [markdown]
# ## Explicit method of solution in finite differences
#
# The finite difference method is probably the most common numerical method for solving PDEs. The derivatives are approximated by Newton difference ratios, and you step through in time to progress the solution from $t=0$ to some ending time.
#
# The following defines a function that solves the wave equation, using an explicit finite difference method. We follow the notes in the referenced book by Myint-U and Debnath.
#
# The differencing in spatial variable $x$ is done by a convolution, as this will be fast.
#
# We print out the value of the CFL constant as a sanity check. The method is stable and convergent provided the CFL value is less than one. (This means $dt$ needs to be small enough.) See the book for details.
#
# The input parameters are velocity squared $c2$, spatial step size $dx$, temporal step size $dt$, number of time steps $t$_$len$, initial position $u0$ and initial velocity $u1$. $u0$ and $u1$ are arrays of some length $N$, which the code will use to deduce everything it needs to know.
#
# I tend to think of these as dimensionless variables, but you can use real physical values if you like, so long as you are consistent. For instance $dx$ in meters, $dt$ in seconds, and $c2$ in (meters/second) squared.

# %%
# Based on Section 14.4 in Myint-U and Debnath's book
def w_solve1(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    e2 = c2*dt*dt/(dx*dx)  # Courant parameter squared (test for convergence!)
    print("CFL value is ",np.sqrt(e2))
    kern = np.array([e2, 2*(1-e2), e2]) # the convolution kernel we need for laplacian solver
    u[:,0] = u0            # t=0 initial condition
    u[:,1] = np.convolve(u0,kern/2)[1:x_len+1] + dt*u1 # t=0 derivative condition, eqn 14.4.6
    for j in range(2,t_len):
        u[:,j] = np.convolve(u[:,j-1],kern)[1:x_len+1] - u[:,j-2] # eqn 14.4.3
    # let's produce the x and t vectors, in case we need them
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    return u,x,t

# %% [markdown]
# Let's try a real wave equation solution.
#
# We start with a simple triangle waveform.

# %%
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# %% [markdown]
# Now we call up our wave equation solver, using the parameters above

# %%
# Here we solve the wave equation, with initial position $u(x,0)$ set to the triangle waveform
(u,x,t)=w_solve1(.5,dx,dt,t_len,triangle,0*triangle)
# Out:
# CFL value is  0.707106781187

# %% [markdown]
# We initialize the plotting tools in Bokeh and plot the initial waveform.

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d5c84586-d8b0-4d20-9456-7985d899ebf7">Loading BokehJS ...</span>
#     </div>

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="F.D. Explicit method solution", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()

show(p)
# Out:
#     <div class="plotdiv" id="1ba3c2cc-21f2-4e95-b433-4e23dade6ece"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1ba3c2cc-21f2-4e95-b433-4e23dade6ece");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1ba3c2cc-21f2-4e95-b433-4e23dade6ece' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"37d1eaa7-1ab4-44da-9985-1cbfdc2522d0":{"roots":{"references":[{"attributes":{"plot":{"id":"f094a9de-701e-452f-b5c5-d4fadb10352c","subtype":"Figure","type":"Plot"}},"id":"d1944a39-f3cc-45c3-aeb1-c0f1bd1971e0","type":"WheelZoomTool"},{"attributes":{},"id":"faa859be-6b6a-4082-ad2e-9c78ed8738c8","type":"BasicTicker"},{"attributes":{"below":[{"id":"3fa84165-054e-40e8-b0a6-0ce48d1e4c87","type":"LinearAxis"}],"left":[{"id":"52ba87be-be9d-497e-a979-76e2dfc5aae2","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":
136,0.137,0.138,0.139,0.14,0.14100000000000001,0.14200000000000002,0.14300000000000002,0.14400000000000002,0.145,0.146,0.147,0.148,0.149,0.15,0.151,0.152,0.153,0.154,0.155,0.156,0.157,0.158,0.159,0.16,0.161,0.162,0.163,0.164,0.165,0.166,0.167,0.168,0.169,0.17,0.171,0.17200000000000001,0.17300000000000001,0.17400000000000002,0.17500000000000002,0.176,0.177,0.178,0.179,0.18,0.181,0.182,0.183,0.184,0.185,0.186,0.187,0.188,0.189,0.19,0.191,0.192,0.193,0.194,0.195,0.196,0.197,0.198,0.199,0.2,0.201,0.202,0.203,0.20400000000000001,0.20500000000000002,0.20600000000000002,0.20700000000000002,0.20800000000000002,0.209,0.21,0.211,0.212,0.213,0.214,0.215,0.216,0.217,0.218,0.219,0.22,0.221,0.222,0.223,0.224,0.225,0.226,0.227,0.228,0.229,0.23,0.231,0.232,0.233,0.234,0.23500000000000001,0.23600000000000002,0.23700000000000002,0.23800000000000002,0.23900000000000002,0.24,0.241,0.242,0.243,0.244,0.245,0.246,0.247,0.248,0.249,0.25,0.251,0.252,0.253,0.254,0.255,0.256,0.257,0.258,0.259,0.26,0.261,0.262,0.263,0.264,0.265,0.266,0.267,0.268,0.269,0.27,0.271,0.272,0.273,0.274,0.275,0.276,0.277,0.278,0.279, ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[8]</strong>&gt;</code></p>

# %% [markdown]
# And the next cell sets up a slider which controls the above graphs (it moves time along)

# %%
# This runs an animation, controlled by a slider which advances time
interact(update,k=(0,t_len-1))

# %% [markdown]
# ### Derivative initial condition test

# %%
# We try again, but this time with the $u_t$ initial condition equal to the triangle impulse
(u,x,t)=w_solve1(.5,dx,dt,3*t_len,0*triangle,1*triangle)
# Out:
# CFL value is  0.707106781187

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="F.D. Explicit method solution, Der Cond", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="4d26a9ac-a236-4cc7-94b8-bd5c004825a2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4d26a9ac-a236-4cc7-94b8-bd5c004825a2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4d26a9ac-a236-4cc7-94b8-bd5c004825a2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a6cb752c-5fb6-44cf-ae20-a8e2f7865c06":{"roots":{"references":[{"attributes":{"plot":{"id":"61f0c663-9945-48a1-b4f7-1150872257bc","subtype":"Figure","type":"Plot"}},"id":"d1f9bb6d-f101-46cc-ab04-f69d242d88b5","type":"ResizeTool"},{"attributes":{"plot":{"id":"10457d5e-71bb-4de3-b39f-54b6ff3b4ba7","subtype":"Figure","type":"Plot"}},"id":"1b3ddd3f-d30d-4873-a616-effaef86c5b8","type":"ResizeTool"},{"attributes":{"formatter":{"id":"3e2fe637-822b-41af-b312-635811a4b235","type":"BasicTickFormatter"},"plot":{"id":"61f0c663-9945-48a1-b4f7-1150872257bc","subtype":"Figure","type":"Plot"},"ticker":{"id":"5408430f-582b-4951-91c2-347c62640a53","type":"BasicTicker"}},"id":"54c34232-421f-43b3-851b-6e0949820110","type":"LinearAxis"},{"attributes":{},"id":"5408430f-582b-4951-91c2-347c62640a53","type":"BasicTicker"},{"attributes":{},"id":"e8d8b907-5b44-4fe3-8145-d46b3a6e6684","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":
.20400000000000001,0.20500000000000002,0.20600000000000002,0.20700000000000002,0.20800000000000002,0.209,0.21,0.211,0.212,0.213,0.214,0.215,0.216,0.217,0.218,0.219,0.22,0.221,0.222,0.223,0.224,0.225,0.226,0.227,0.228,0.229,0.23,0.231,0.232,0.233,0.234,0.23500000000000001,0.23600000000000002,0.23700000000000002,0.23800000000000002,0.23900000000000002,0.24,0.241,0.242,0.243,0.244,0.245,0.246,0.247,0.248,0.249,0.25,0.251,0.252,0.253,0.254,0.255,0.256,0.257,0.258,0.259,0.26,0.261,0.262, ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[45]</strong>&gt;</code></p>

# %%
interact(update,k=(0,3*t_len-1))
# Out:
# <function __main__.update>

# %% [markdown]
# ## Implicit method
#
# Here we try an implicit method for solving the wave equation. Again from Myint-U and Debnath's book, in Section 14.5, part (B) on Hyperbolic equations.
#
# We need to use scipy libraries as we have to solve a system of linear equation. In fact the system is tridiagonal and Toepliz, so this should be fast. I see how to use Toepliz in scipy, but I don't know how to tell it that the system is only tridiagonal. It should be possible to speed this up.

# %%
# Based on Section 14.5 (B) in Myint-U and Debnath's book
def w_solve2(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    e2 = c2*dt*dt/(dx*dx)  # Courant parameter squared (test for convergence!)
    print("CFL value is ",np.sqrt(e2))
    kern = np.array([e2, 2*(1-e2), e2]) # the convolution kernel we need for laplacian solver
    u[:,0] = u0            # t=0 initial condition
    u[:,1] = np.convolve(u0,kern/2)[1:x_len+1] + dt*u1 # t=0 derivative condition, eqn 14.4.6
    # Note the above is a cheat, we are using the explicit method to find u[:,1], Should do this implicitly
    kern2 = np.array([e2, -2*(1+e2), e2]) # the convolution kernel we need for implicit solver. It is different.
    toepk = np.zeros(x_len)  # this will hold the entries for the tridiagonal Toeplitz matrix
    toepk[0] = 2*(1+e2);
    toepk[1] = -e2
    for j in range(2,t_len):
        rhs = np.convolve(u[:,j-2],kern2)[1:x_len+1] + 4*u[:,j-1] # eqn 14.5.17
        u[:,j] = solve_toeplitz(toepk, rhs) # here is a linear system solver (hence an implicit method)
    # let's produce the x and t vectors, in case we need them
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    return u,x,t

# %%
(u,x,t)=w_solve2(.5,dx,dt,t_len,1*triangle,0*triangle)
# Out:
# CFL value is  0.707106781187

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="Implicit solution method", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="439da7a2-2487-4f86-8e87-c161be72d950"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("439da7a2-2487-4f86-8e87-c161be72d950");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '439da7a2-2487-4f86-8e87-c161be72d950' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"
type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"e99bb1d8-bb58-4dba-a8c0-601fc2b09476","type":"Line"},{"attributes":{},"id":"5b16909c-e817-4ff7-8bda-d8e5411c4113","type":"BasicTicker"},{"attributes":{"overlay":{"id":"03d77ae1-30cd-4d77-9ed0-fd50ca702eec","type":"BoxAnnotation"},"plot":{"id":"e2f2eefb-3bf7-46c9-9975-4eacf0dddde0","subtype":"Figure","type":"Plot"}},"id":"29c8a210-e1f6-4f55-838a-65d795871a56","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"b12cd263-9bd7-4df3-a107-4b06c117c0ca","type":"BasicTickFormatter"},"plot":{"id":"e171531e-d1c9-425e-9e48-030a9c5d04b3","subtype":"Figure","type":"Plot"},"ticker":{"id":"36c9dcec-6ca3-4d2f-9de2-c9bb851338c9","type":"BasicTicker"}},"id":"84292a7a-5652-4123-afb6-f89d6d83c96b","type":"LinearAxis"},{"attributes":{},"id":"46b6ab8d-8f0a-4052-a0d7-9ea752f6cb6a","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"47870ee2-7a2d-4f04-8e11-a90a5e ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[49]</strong>&gt;</code></p>

# %%
interact(update,k=(0,3*t_len-1))
# Out:
# <function __main__.update>

# %% [markdown]
# ### Derivative initial condition

# %%
(u,x,t)=w_solve2(.5,dx,dt,3*t_len,0*triangle,1*triangle)
# Out:
# CFL value is  0.707106781187

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="Implicit solution method, Der cond", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="fe3dccbe-21b3-448d-aec9-b418a109fa1c"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fe3dccbe-21b3-448d-aec9-b418a109fa1c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fe3dccbe-21b3-448d-aec9-b418a109fa1c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cd11ed2a-e18c-4ab7-b4d2-ee73bcaa0165":{"roots":{"references":[{"attributes":{"plot":{"id":"f4be312f-7279-4c62-9042-653de1cc88c8","subtype":"Figure","type":"Plot"}},"id":"a8717712-3657-4b18-82de-c4a3f58612dc","type":"ResetTool"},{"attributes":{"plot":{"id":"61f0c663-9945-48a1-b4f7-1150872257bc","subtype":"Figure","type":"Plot"}},"id":"d1f9bb6d-f101-46cc-ab04-f69d242d88b5","type":"ResizeTool"},{"attributes":{"plot":{"id":"10457d5e-71bb-4de3-b39f-54b6ff3b4ba7","subtype":"Figure","type":"Plot"}},"id":"1b3ddd3f-d30d-4873-a616-effaef86c5b8","type":"ResizeTool"},{"attributes":{"formatter":{"id":"3e2fe637-822b-41af-b312-635811a4b235","type":"BasicTickFormatter"},"plot":{"id":"61f0c663-9945-48a1-b4f7-1150872257bc","subtype":"Figure","type":"Plot"},"ticker":{"id":"5408430f-582b-4951-91c2-347c62640a53","type":"BasicTicker"}},"id":"54c34232-421f-43b3-851b-6e0949820110","type":"LinearAxis"},{"attributes":{},"id":"bab819c2-82e2-4e78-9ca1-577dc4f34c28","type":"BasicTicker"},{"attributes":{},"id":"e8d8b907-5b44-4fe3-8145-d46b3a6e6684","type":"BasicTickFormatter"
...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[52]</strong>&gt;</code></p>

# %%
interact(update,k=(0,3*t_len-1))

# %% [markdown]
# ## D'Alembert's solution
#
# Since the velocity $c$ is constant in these examples, we can get the exact solution via D'Alembert. The general solution will be of the form
# $$u(x,t) = \phi(x+ct) + \psi(x-ct). $$
# Initial conditions tell use that
# $$u(x,0) = \phi(x) + \psi(x) = f(x), $$ and
# $$u_t(x,0) = c\phi'(x) - c\psi'(x) = g(x). $$
# With $G(x)$ the antiderivative of $g(x)$ with appropriate zero at zero, we get a 2x2 system
# $$\phi(x) + \psi(x) = f(x), \\ c(\phi(x) - \psi(x)) = G(x),$$
# which we solve as
# $$\phi(x) = \frac{1}{2}\left( f(x) + \frac{1}{c} G(x) \right), \\
#   \psi(x) = \frac{1}{2}\left( f(x) - \frac{1}{c} G(x) \right).$$
#
# Now $f(x)$ is given as the argument $u0$ in the code. $G(x)$ can be computed using scipy. The arguments $x+ct$ and $x-ct$ must be converted to integer indices. They have to wrap around. And with the zero boundary condition, we need to wrap around with a negative reflection.
#
# There is the messy question as to whether we require $u(0,t)$ to actually equal zero, or do we require it to be zero one index "to the left" of x=0. Let's not think too much about that just yet.

# %%
# Based on D'Alembert's solution, as described above
def w_solve3(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    c = np.sqrt(c2)  # the actual velocity parameter is needed
    f = u0  # use notation from above notes
    G = cumtrapz(u1,dx=dx,initial=0) # the antiderivative, using cumulative trapezoidal rule
    f2 = np.append(f,-f[::-1]) # odd symmetry
    G2 = np.append(G,G[::-1]) # even symmetry
    phi2 = (f2 + G2/c)/2
    psi2 = (f2 - G2/c)/2
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    # in the loop, we convert x+ct to index's into vectors phi2, psi2, modulo the vector length
    for j in range(t_len):
        ii1 = np.mod( np.round((x+c*t[j])/dx), 2*x_len)
        ii2 = np.mod( np.round((x-c*t[j])/dx), 2*x_len)
        u[:,j] = phi2[ii1.astype(int)] + psi2[ii2.astype(int)]
    return u,x,t

# %%
(u,x,t)=w_solve3(.5,dx,dt,t_len,1*triangle,0*triangle)

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert solution", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="cbf2842f-ec40-4f55-ba0b-0821eb35fbc3"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cbf2842f-ec40-4f55-ba0b-0821eb35fbc3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cbf2842f-ec40-4f55-ba0b-0821eb35fbc3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {
},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"e99bb1d8-bb58-4dba-a8c0-601fc2b09476","type":"Line"},{"attributes":{},"id":"5b16909c-e817-4ff7-8bda-d8e5411c4113","type":"BasicTicker"},{"attributes":{"overlay":{"id":"03d77ae1-30cd-4d77-9ed0-fd50ca702eec","type":"BoxAnnotation"},"plot":{"id":"e2f2eefb-3bf7-46c9-9975-4eacf0dddde0","subtype":"Figure","type":"Plot"}},"id":"29c8a210-e1f6-4f55-838a-65d795871a56","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"b12cd263-9bd7-4df3-a107-4b06c117c0ca","type":"BasicTickFormatter"},"plot":{"id":"e171531e-d1c9-425e-9e48-030a9c5d04b3","subtype":"Figure","type":"Plot"},"ticker":{"id":"36c9dcec-6ca3-4d2f-9de2-c9bb851338c9","type":"BasicTicker"}},"id":"84292a7a-5652-4123-afb6-f89d6d83c96b","type":"LinearAxis"},{"attributes":{},"id":"46b6ab8d-8f0a-4052-a0d7-9ea752f6cb6a","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"47870ee2-7a2d-4f04-8e11-a90a5e6910ab","type":" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[56]</strong>&gt;</code></p>

# %%
interact(update,k=(0,t_len-1))
# Out:
# <function __main__.update>

# %% [markdown]
# ### Derivative initial condition

# %%
(u,x,t)=w_solve3(.5,dx,dt,3*t_len,0*triangle,1*triangle)

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert solution, Der Cond", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="48d9133b-8386-4d57-bfd3-7dd45bae4c06"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("48d9133b-8386-4d57-bfd3-7dd45bae4c06");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '48d9133b-8386-4d57-bfd3-7dd45bae4c06' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3328111a-7f0b-41df-b1a2-48128f2a4085":{"roots":{"references":[{"attributes":{},"id":"bab819c2-82e2-4e78-9ca1-577dc4f34c28","type":"BasicTicker"},{"attributes":{"plot":{"id":"61f0c663-9945-48a1-b4f7-1150872257bc","subtype":"Figure","type":"Plot"}},"id":"d1f9bb6d-f101-46cc-ab04-f69d242d88b5","type":"ResizeTool"},{"attributes":{"formatter":{"id":"3e2fe637-822b-41af-b312-635811a4b235","type":"BasicTickFormatter"},"plot":{"id":"61f0c663-9945-48a1-b4f7-1150872257bc","subtype":"Figure","type":"Plot"},"ticker":{"id":"5408430f-582b-4951-91c2-347c62640a53","type":"BasicTicker"}},"id":"54c34232-421f-43b3-851b-6e0949820110","type":"LinearAxis"},{"attributes":{},"id":"e8d8b907-5b44-4fe3-8145-d46b3a6e6684","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"bc29c6f9-705d-4c40-90cf-d04212879683","subtype":"Figure","type":"Plot"}},"id":"56bb6a4a-237d-44ab-b380-7d3b40414ac7","type":"WheelZoomTool"},{"attributes":{},"id":"bd525473-bd71-439a-805c-6a5f40ffa368","type":"ToolEvents"},{"attributes":{"plot":{"id":"10457d5e-71bb-4de3-b39f-54b6ff3b4ba7","subtype":"Figure","type":"Plot"}},"id":"38cd25cf-8a03-4ae5-9236-6fdab1af18c9","type":"PanTool"},{"attributes":{},"id":"020d2b15-fbda-4b12-852f-50a5d61906b1","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"e99bb1d8-bb58-4dba-a8c0-601fc2b09476","type":"Line"},{"attributes":{},"id":"5b16909c-e817-4ff7-8bda-d8e5411c4113","type":"BasicTicker"},{"attributes":{"overlay":{"id":"03d77ae1-30cd-4d77-9ed0-fd50ca702eec","type":"BoxAnnotation"},"plot":{"id":"e2f2eefb-3bf7-46c9-9975-4eacf0dddde0","subtype":"Figure","type":"Plot"}},"id":"29c8a210-e1f6-4f55-838a-65d795871a56","type":"BoxZoomTool"},{"attributes":{},"id":"46b6ab8d-8f0a-4052-a0d7-9ea752f6cb6a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"61f0c663-9945-48a1-b4f7-1150872257bc","subtype":"Figure","type":"Plot"}},"id":"a4861040-3b72-4b1b-99ba-b0b0c5d4a53f","type":"ResetTool"},{"attributes":{"data_source":{"id":"ea624ad3-fcb2-4f4f-9ba4-c044460b4c7b","type":"ColumnDataSource"},"glyph":{"id":"da12b23b-f9f7-4b11-818f-384ce7818d25","type":"Line"},"hover_glyph":null,"name":"foo","nonselection_glyph":{"id":"95eed404-0ea1-4b28-9fa0-a2720bef4c86","type":"Line"},"selection_glyph":null},"id":"45857e17-48ed-44d0-9c10-e1a1b653d6ef","type":"GlyphRenderer"},{"attributes":{},"id":"9f74da1d-c6e9-43a0-b9f7-f367ec90dbad","type":"BasicTicker"},{"attributes":{"plot":{"id":"de3695fa-1bcd-401f-b4ad-39c2098fd865","subtype":"Figure","type":"Plot"},"ticker":{"id":"5d39dd9e-1819-4810-adf7-6b26da4d1519","type":"BasicTicker"}},"id":"45100916-04e7-4859-9ada-c23af74c6789","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4203a7e4-49c5-47ae-91f4-ad9eaa72503a","type":"BoxAnnotation"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7be65f8c-dd4d-46b0-b659-feefbb688e8f","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"aab69a6e-c762-4d52-abd6-1177c5ef62f2","subtype":"Figure","type":"Plot"}},"id":"4202e018-eaae-4cf8-be36-e0bdedfadf8a","type":"ResetTool"},{"attributes":{"callback":null},"id":"b6f41f09-b03c-4616-aa02-b822a3708f85","type":"DataRange1d"},{"attributes":{"plot":{"id":"61f0c663-9945-48a1-b4f7-1150872257bc","subtype":"Figure","type":"Plot"}},"id":"8fee2a72-2cc3-40fe-a06e-4f7dd817a318","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x": ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[59]</strong>&gt;</code></p>

# %%
interact(update,k=(0,3*t_len-1))
# Out:
# <function __main__.update>

# %% [markdown]
# # Comparing solutions
#
# In principle, we want these different solution methods to be directly comparable.
#
# So let's try this out, by computing the difference of two solution.
#
# Here we compare the explicit f.d. method with d'Alambert's method.

# %%
(u_exp,x,t)=w_solve1(.5,dx,dt,t_len,1*triangle,0*triangle)
(u_dal,x,t)=w_solve3(.5,dx,dt,t_len,1*triangle,0*triangle)
# Out:
# CFL value is  0.707106781187

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert minus explicit", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")

def update(k=0):
    src.data['y']=u_dal[:,k]-u_exp[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="93064421-77f6-4936-844f-f7f683a9765d"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById
type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4203a7e4-49c5-47ae-91f4-ad9eaa72503a","type":"BoxAnnotation"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7be65f8c-dd4d-46b0-b659-feefbb688e8f","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"aab69a6e-c762-4d52-abd6-1177c5ef62f2","subtype":"Figure","type":"Plot"}},"id":"4202e018-eaae-4cf8-be36-e0bdedfadf8a","type":"ResetTool"},{"attributes":{"callback":null},"id":"b6f41f09-b03c-4616-aa02-b822a3708f85","type":"DataRange1d ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[62]</strong>&gt;</code></p>

# %%
interact(update,k=(0,t_len-1))
# Out:
# <function __main__.update>

# %% [markdown]
# ## A moving wavefront
#
# Let's try an actual wave. We want something like
# $$u(x,t) = \exp(-(x -x_a-ct)^2/w^2), $$
# where $x_a$ is the center of the Gaussian at $t=0$, $w$ is the width of the Gaussian, $c$ is the velocity of the wave.
#
# This gives
# $$u_0(x) = \exp(-(x -x_a)^2/w^2) \\
#   u_1(x) = \frac{2c(x-x_a)}{w^2}\exp(-(x -x_a)^2/w^2) = \frac{2c(x-x_a)}{w^2}u_0(x).$$

# %%
c = .707  # velocity
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
u0 = np.exp(-(x-.5)*(x-.5)/.01)
u1 = 2*c*u0*(x-.5)/.01

# %%
(u,x,t)=w_solve3(c*c,dx,dt,t_len,u0,u1)  # notice we input the velocity squared!

# %%
y=u[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))
p = figure(title="Moving wave", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="ce1311ac-a451-411d-86d2-a1159b5caef0"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ce1311ac-a451-411d-86d2-a1159b5caef0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ce1311ac-a451-411d-86d2-a1159b5caef0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5fb9e2c6-a4ed-49f8-986f-6689ba3b99bd":{"roots":{"references":[{"attributes":{},"id":"ac72fd48-9379-49b7-b74b-e24fb7e38d1f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"61f0c663-9945-48a1-b4f7-1150872257bc","subtype":"Figure","type":"Plot"}},"id":"d1f9bb6d-f101-46cc-ab04-f69d242d88b5","type":"ResizeTool"},{"attributes":{"formatter":{"id":"3e2fe637-822b-41af-b312-635811a4b235","type":"BasicTickFormatter"},"plot":{"id":"61f0c663-9945-48a1-b4f7-1150872257bc","subtype":"Figure","type":"Plot"},"ticker":{"id":"5408430f-582b-4951-91c2-347c62640a53","type":"BasicTicker"}},"id":"54c34232-421f-43b3-851b-6e0949820110","type":"LinearAxis"},{"attributes":{},"id":"bab819c2-82e2-4e78-9ca1-577dc4f34c28","type":"BasicTicker"},{"attributes":{},"id":"e8d8b907-5b44-4fe3-8145-d46b3a6e6684","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"bc29c6f9-705d-4c40-90cf-d04212879683","subtype":"Figure","type":"Plot"}},"id":"56bb6a4a-237d-44ab-b380-7d3b40414ac7","type":"WheelZoomTool"},{"attributes":{},"id":"bd525473-bd71-439a-805c-6a5f40ffa368","type":"ToolEvents"},{"attributes":{"plot":{"id":"10457d5e-71bb-4de3-b39f-54b6ff3b4ba7","subtype":"Figure","type":"Plot"}},"id":"38cd25cf-8a03-4ae5-9236-6fdab1af18c9","type":"PanTool"},{"attributes":{"plot":{"id":"53d0a168-147e-4a3e-ad87-56f56718f8fb","subtype":"Figure","type":"Plot"}},"id":"efeab05c-b76b-467e-8120-7c88016403ea","type":"ResizeTool"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"e99bb1d8-bb58-4dba-a8c0-601fc2b09476","type":"Line"},{"attributes":{},"id":"5b16909c-e817-4ff7-8bda-d8e5411c4113","type":"BasicTicker"},{"attributes":{"overlay":{"id":"03d77ae1-30cd-4d77-9ed0-fd50ca702eec","type":"BoxAnnotation"},"plot":{"id":"e2f2eefb-3bf7-46c9-9975-4eacf0dddde0","subtype":"Figure","type":"Plot"}},"id":"29c8a210-e1f6-4f55-838a-65d795871a56","type":"BoxZoomTool"},{"attributes":{},"id":"46b6ab8d-8f0a-4052-a0d7-9ea752f6cb6a","type":"BasicTickFormatter"},{"attributes":{},"id":"77c62f8f-d568-40cc-8dc6-2c026aec5af3","type":"ToolEvents"},{"attributes":{"plot":{"id":"61f0c663-9945-48a1-b4f7-1150872257bc","subtype":"Figure","type":"Plot"}},"id":"a4861040-3b72-4b1b-99ba-b0b0c5d4a53f","type":"ResetTool"},{"attributes":{"callback":null},"id":"3dc8fdbc-4f08-4130-aed4-1849d37467e1","type":"DataRange1d"},{"attributes":{"data_source":{"id":"ea624ad3-fcb2-4f4f-9ba4-c044460b4c7b","type":"ColumnDataSource"},"glyph":{"id":"da12b23b-f9f7-4b11-818f-384ce7818d25","type":"Line"},"hover_glyph":null,"name":"foo","nonselection_glyph":{"id":"95eed404-0ea1-4b28-9fa0-a2720bef4c86","type":"Line"},"selection_glyph":null},"id":"45857e17-48ed-44d0-9c10-e1a1b653d6ef","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"e2d7105b-de64-4d5b-888c-74c902babc51","subtype":"Figure","type":"Plot"}},"id":"daea4c88-5ab4-454e-b48c-49bcffe3f4af","type":"HelpTool"},{"attributes":{},"id":"9f74da1d-c6e9-43a0-b9f7-f367ec90dbad","type":"BasicTicker"},{"attributes":{"plot":{"id":"e171531e-d1c9-425e-9e48-030a9c5d04b3","subtype":"Figure","type":"Plot"}},"id":"16d8ff3c-ff46-4625-916f-9e9833a4b1bb","type":"PanTool"},{"attributes":{"plot":{"id":"de3695fa-1bcd-401f-b4ad-39c2098fd865","subtype":"Figure","type":"Plot"},"ticker":{"id":"5d39dd9e-1819-4810-adf7-6b26da4d1519","type":"BasicTicker"}},"id":"45100916-04e7-4859-9ada-c23af74c6789","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4203a7e4-49c5-47ae-91f4-ad9eaa72503a","type":"BoxAnnotation"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"lin ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[66]</strong>&gt;</code></p>

# %%
interact(update,k=(0,t_len-1))
