# %%
using PyCall

# %%
@pyimport math

# %%
math.sin(.1)
# Out:
# 0.09983341664682815

# %%
@pyimport pywt

# %%
pywt.dwt([1 2 3 4],"db1")
# Out:
# (
# [2.12132 4.94975],
#
# [-0.707107 -0.707107])

# %%
@pyimport IPython.display as ip

# %%
Fs = 8000.0
Len = 5
t = linspace(0,Len,Fs*Len)
f1 = 442.0
f2 = 440.0
signal = sin(2*pi*f1*t) + sin(2*pi*f2*t)
# Out:
# 40000-element Array{Float64,1}:
#   0.0
#   0.67897
#   1.27729
#   1.7239
#   1.96575
#   1.9741
#   1.74798
#   1.31424
#   0.724407
#   0.0485328
#  -0.633099
#  -1.23952
#  -1.69872
#   ⋮
#   1.23952
#   0.633099
#  -0.0485328
#  -0.724407
#  -1.31424
#  -1.74798
#  -1.9741
#  -1.96575
#  -1.7239
#  -1.27729
#  -0.67897
#  -9.52241e-13

# %%
ip.Audio(data=signal, rate=Fs)
# Out:
# PyObject <IPython.lib.display.Audio object>
# WARNING: Base.writemime is deprecated.
#   likely near /opt/julia-0.5.0/share/julia/site/v0.5/IJulia/src/kernel.jl:31
# WARNING: Base.writemime is deprecated.
#   likely near /opt/julia-0.5.0/share/julia/site/v0.5/IJulia/src/kernel.jl:31
# WARNING: Base.writemime is deprecated.
#   likely near /opt/julia-0.5.0/share/julia/site/v0.5/IJulia/src/kernel.jl:31
# WARNING: Base.writemime is deprecated.
#   likely near /opt/julia-0.5.0/share/julia/site/v0.5/IJulia/src/kernel.jl:31
# WARNING: Base.writemime is deprecated.
#   likely near /opt/julia-0.5.0/share/julia/site/v0.5/IJulia/src/kernel.jl:31
# WARNING: Base.writemime is deprecated.
#   likely near /opt/julia-0.5.0/share/julia/site/v0.5/IJulia/src/kernel.jl:31
# WARNING: Base.writemime is deprecated.
#   likely near /opt/julia-0.5.0/share/julia/site/v0.5/IJulia/src/kernel.jl:31
# WARNING: Base.writemime is deprecated.
# ...

# %%
pywt.families()
# Out:
# 14-element Array{Any,1}:
#  "haar"
#  "db"
#  "sym"
#  "coif"
#  "bior"
#  "rbio"
#  "dmey"
#  "gaus"
#  "mexh"
#  "morl"
#  "cgau"
#  "shan"
#  "fbsp"
#  "cmor"
